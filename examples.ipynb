# %% [markdown]
# # Examples
# ---
# Notebook to provide some examples of the nhl pbp data scraper

# %% [markdown]
# #### Import modules

# %%
import pandas as pd
import nhl_pbp_data_scraper as nhlpbpds

# %% [markdown]
# #### Scrape single game

# %%
# Pass in a game id
game_id = 2023020350
single_game_pbp = nhlpbpds.scrape_game(game_id)
single_game_pbp
# Out:
# Scraping game 2023020351...
# Game 2023020351 finished.
#         game_id  game_season  game_date  game_type                  venue  \
# 0    2023020351     20232024          2          2  Scotiabank Saddledome
# 1    2023020351     20232024          2          2  Scotiabank Saddledome
# 2    2023020351     20232024          2          2  Scotiabank Saddledome
# 3    2023020351     20232024          2          2  Scotiabank Saddledome
# 4    2023020351     20232024          2          2  Scotiabank Saddledome
# ..          ...          ...        ...        ...                    ...
# 291  2023020351     20232024          2          2  Scotiabank Saddledome
# 292  2023020351     20232024          2          2  Scotiabank Saddledome
# 293  2023020351     20232024          2          2  Scotiabank Saddledome
# 294  2023020351     20232024          2          2  Scotiabank Saddledome
# 295  2023020351     20232024          2          2  Scotiabank Saddledome
#
# ...

# %% [markdown]
# #### Scrape games from a certain date

# %%
# Format is YYYY-MM-DD
date = "2023-12-20"
date_pbp = nhlpbpds.scrape_date(date)
date_pbp
# Out:
# Scraping games from 2023-12-20...
#
# Scraping game 2023020495...
# Game 2023020495 finished.
#
# Scraping game 2023020496...
# Game 2023020496 finished.
#
# Scraping game 2023020497...
# Game 2023020497 finished.
#         game_id  game_season  game_date  game_type               venue  \
# 0    2023020495     20232024          2          2  Canada Life Centre
# 1    2023020495     20232024          2          2  Canada Life Centre
# 2    2023020495     20232024          2          2  Canada Life Centre
# 3    2023020495     20232024          2          2  Canada Life Centre
# 4    2023020495     20232024          2          2  Canada Life Centre
# ..          ...          ...        ...        ...                 ...
# 325  2023020497     20232024          2          2    Crypto.com Arena
# 326  2023020497     20232024          2          2    Crypto.com Arena
# 327  2023020497     20232024          2          2    Crypto.com Arena
# ...
